# %% [markdown]
# **Functions**

# %% [markdown]
# A function is a block of code which only runs when it is called.
# A function can return data as a result.
# A function helps avoiding code repetition

# %% [markdown]
# In Python, a function is defined using the def keyword, followed by a function name and parentheses:

# %% [markdown]
# A function is a block of code which only runs when it is called.<br>
# A function can return data as a result.<br>
# A function helps avoiding code repetition.<br>

# %% [markdown]
# **Creating Functions**

# %% [raw]
# Functions are created using "def" Keyword

# %%
def my_function():
  print("Hello from a function")

# %% [markdown]
# Arguments are passed inside parenthesis , we can pass 0 , 1 or multiple arguments

# %% [markdown]
# **Calling Function**

# %%
my_function()
# Out:
# Hello from a function

# %% [markdown]
# <br><b> Parameter vs Argument </b>

# %% [markdown]
# The terms parameter and argument can be used for the same thing: information that are passed into a function.

# %% [markdown]
# From a function's perspective:<br>
# A parameter is the variable listed inside the parentheses in the function definition.<br>
# An argument is the actual value that is sent to the function when it is called.<br>

# %%
def my_function(name): # name is a parameter
  print("Hello", name)

my_function("Emil") # "Emil" is an argument
# Out:
# Hello Emil

# %% [markdown]
# <br><h3>Function Arguments</h3>

# %% [markdown]
# <b>~Default argument<br>
# ~Keyword arguments (named arguments)<br>
# ~Positional arguments<br>

# %% [markdown]
# <br><b>Default Arguments</b>

# %%
def calculate_area(length, width=5):
    area = length * width
    print(f"Area of rectangle: {area}")
    # Driver code (We call calculate_area() with only
    # the length argument)
    
calculate_area(10) # we have passed value of length only , width will be by default = 5
# We can also pass a custom width
calculate_area(10, 8)
# Out:
# Area of rectangle: 50
# Area of rectangle: 80

# %% [markdown]
# <br><b>Keyword arguments</b>

# %% [markdown]
# Keyword arguments are passed by naming the parameters when calling the function. This lets us provide the arguments in any order, making the code more readable and flexible.

# %%
def fun(name, course):
    print(name,course)
# Positional arguments
fun(course="DSA",name="gfg")
fun(name="gfg",course="DSA")
# Out:
# gfg DSA
# gfg DSA

# %% [markdown]
# <br>
# <b>Positional Arguments</b>

# %% [markdown]
# When you call a function with arguments without using keywords, they are called positional arguments. Positional arguments must be in the correct order:

# %%
def my_function(animal, name):
  print("I have a", animal)
  print("My", animal + "'s name is", name)

my_function("dog", "Buddy")
# Out:
# I have a dog
# My dog's name is Buddy
