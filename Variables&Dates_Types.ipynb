# %%
var1 = True           #this is variable defination

# %%
num1 = 23         #int

# %%
num2 = 23.23     #float

# %%
name = "Ishan"   #string

# %%
indian = True    # boolean

# %%
li  = [23 , 4.23 , False , "Hello"]      #list

# %%
tup = (34, 5.34 , "World")            #tuple

# %%
dic = {"name":"Ishan" , "roll":23 , "city":"A.Nagar"}

# %%
type(dic)
# Out:
# dict

# %%
type(tup)
# Out:
# tuple

# %%
type(num1)
# Out:
# int

# %%
type(num2)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
type(indian)
# Out:
# bool

# %%
type(li)
# Out:
# list
