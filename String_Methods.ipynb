# %% [markdown]
# **String Methods**

# %% [markdown]
# string methods are the functions which are used for performing specific operation on string

# %% [markdown]
# There are various methods

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
" Hello ".strip()
# Out:
# 'Hello'

# %%
"hello world".split()
# Out:
# ['hello', 'world']

# %%
"-".join(["2025", "04", "14"])
# Out:
# '2025-04-14'

# %%
"python".find("th")
# Out:
# 2

# %% [markdown]
# This are some examples of string methods
